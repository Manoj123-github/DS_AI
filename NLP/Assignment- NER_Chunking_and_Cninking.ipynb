# %%
import nltk
nltk.download('gutenberg')
from nltk.corpus import gutenberg
# Out:
# [nltk_data] Downloading package gutenberg to C:\Users\Manoj
# [nltk_data]     Yadav\AppData\Roaming\nltk_data...
# [nltk_data]   Package gutenberg is already up-to-date!

# %%
sent=gutenberg.raw('C:/Users/Manoj Yadav/Desktop/RJ.txt')
sent
# Out:
# 'On the auspicious day of Shri Krishna Janmashtami, 15th August 1938, the people of Ghatkopar and the surrounding suburbs witnessed the birth of Hindi Vidya Prachar Samiti, a brain child of a visionary Late Shri Nandkishore Singh Jairamji. The Samiti was established with the objectives of catering to the educational needs of the Hindi speaking community. It made a humble beginning by starting a primary school, which gradually expanded into a full-fledged secondary school.\r\nThe Hindi High School with its high academic standards has carved for itself a place not only among leading secondary schools in Mumbai but also educational institutions imparting instructions in Hindi throughout Maharashtra. With its primary objectives achieved the Samiti decided to extend its frontiers and broaden its horizons. As a result, Ramniranjan Jhunjhunwala College came into existence in 1963, enabling a larger section of the society to take advantage of the facilities provided for higher education.\r\nIn 1976 the Junior College section was introduced and in 1981 the Commerce faculty commenced both at the Junior and Degree College level.\r\nFrom 1999-2000 the College has added a number of self-financing courses like BMS, B.B.I, B.Sc. in C.S., I.T., Biotechnology, M.Sc. in Computer Science and Biotechnology as well as add on courses, which further hone the special skills of the students.\r\nIn 2014 saw a change in education system with greater emphasis being given to employability of youth. As an effort to realize the dream of Make in India, Digital India, Clean and Green India, we have started skill based program supported by University Grants commission known as Bachelor in Vocation.'

# %%
from nltk.tokenize import word_tokenize
from nltk.tag import pos_tag

# %%
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to C:\Users\Manoj
# [nltk_data]     Yadav\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Manoj Yadav\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# True

# %%
words= word_tokenize(sent)
postags=pos_tag(words)
postags
# Out:
# [('On', 'IN'),
#  ('the', 'DT'),
#  ('auspicious', 'JJ'),
#  ('day', 'NN'),
#  ('of', 'IN'),
#  ('Shri', 'NNP'),
#  ('Krishna', 'NNP'),
#  ('Janmashtami', 'NNP'),
#  (',', ','),
#  ('15th', 'CD'),
#  ('August', 'NNP'),
#  ('1938', 'CD'),
#  (',', ','),
#  ('the', 'DT'),
#  ('people', 'NNS'),
#  ('of', 'IN'),
#  ('Ghatkopar', 'NNP'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('surrounding', 'VBG'),
#  ('suburbs', 'NNS'),
#  ('witnessed', 'VBD'),
#  ('the', 'DT'),
#  ('birth', 'NN'),
#  ('of', 'IN'),
#  ('Hindi', 'NNP'),
#  ('Vidya', 'NNP'),
#  ('Prachar', 'NNP'),
#  ('Samiti', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('brain', 'NN'),
#  ('child', 'NN'),
#  ('of', 'IN'),
#  ('a', 'DT'),
#  ('visionary', 'JJ'),
#  ('Late', 'NNP'),
#  ('Shri', 'NNP'),
#  ('Nandkishore', 'NNP'),
#  ('Singh', 'NNP'),
#  ('Jairamji', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('Samiti', 'NNP'),
#  ('was', 'VBD'),
#  ('established', 'VBN'),
#  ('with', 'IN'),
#  ('the', 'DT'),
#  ('objectives', 'NNS'),
#  ('of', 'IN'),
#  ('catering', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('educational', 'JJ'),
#  ('needs', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Hindi', 'NNP'),
#  ('speaking', 'NN'),
#  ('community', 'NN'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('made', 'VBD'),
#  ('a', 'DT'),
#  ('humble', 'JJ'),
#  ('beginning', 'NN'),
#  ('by', 'IN'),
#  ('starting', 'VBG'),
#  ('a', 'DT'),
#  ('primary', 'JJ'),
#  ('school', 'NN'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('gradually', 'RB'),
#  ('expanded', 'VBD'),
#  ('into', 'IN'),
#  ('a', 'DT'),
#  ('full-fledged', 'JJ'),
#  ('secondary', 'JJ'),
#  ('school', 'NN'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('Hindi', 'NNP'),
#  ('High', 'NNP'),
#  ('School', 'NNP'),
#  ('with', 'IN'),
#  ('its', 'PRP$'),
#  ('high', 'JJ'),
#  ('academic', 'JJ'),
#  ('standards', 'NNS'),
#  ('has', 'VBZ'),
#  ('carved', 'VBN'),
#  ('for', 'IN'),
#  ('itself', 'PRP'),
#  ('a', 'DT'),
#  ('place', 'NN'),
#  ('not', 'RB'),
#  ('only', 'RB'),
#  ('among', 'IN'),
#  ('leading', 'VBG'),
#  ('secondary', 'JJ'),
#  ('schools', 'NNS'),
#  ('in', 'IN'),
#  ('Mumbai', 'NNP'),
#  ('but', 'CC'),
#  ('also', 'RB'),
#  ('educational', 'JJ'),
#  ('institutions', 'NNS'),
#  ('imparting', 'VBG'),
#  ('instructions', 'NNS'),
#  ('in', 'IN'),
#  ('Hindi', 'NNP'),
#  ('throughout', 'IN'),
#  ('Maharashtra', 'NNP'),
#  ('.', '.'),
#  ('With', 'IN'),
#  ('its', 'PRP$'),
#  ('primary', 'JJ'),
#  ('objectives', 'NNS'),
#  ('achieved', 'VBD'),
#  ('the', 'DT'),
#  ('Samiti', 'NNP'),
#  ('decided', 'VBD'),
#  ('to', 'TO'),
#  ('extend', 'VB'),
#  ('its', 'PRP$'),
#  ('frontiers', 'NNS'),
#  ('and', 'CC'),
#  ('broaden', 'VB'),
#  ('its', 'PRP$'),
#  ('horizons', 'NNS'),
#  ('.', '.'),
#  ('As', 'IN'),
#  ('a', 'DT'),
#  ('result', 'NN'),
#  (',', ','),
#  ('Ramniranjan', 'NNP'),
#  ('Jhunjhunwala', 'NNP'),
#  ('College', 'NNP'),
#  ('came', 'VBD'),
#  ('into', 'IN'),
#  ('existence', 'NN'),
#  ('in', 'IN'),
#  ('1963', 'CD'),
#  (',', ','),
#  ('enabling', 'VBG'),
#  ('a', 'DT'),
#  ('larger', 'JJR'),
#  ('section', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('society', 'NN'),
#  ('to', 'TO'),
#  ('take', 'VB'),
#  ('advantage', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('facilities', 'NNS'),
#  ('provided', 'VBD'),
#  ('for', 'IN'),
#  ('higher', 'JJR'),
#  ('education', 'NN'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('1976', 'CD'),
#  ('the', 'DT'),
#  ('Junior', 'NNP'),
#  ('College', 'NNP'),
#  ('section', 'NN'),
#  ('was', 'VBD'),
#  ('introduced', 'VBN'),
#  ('and', 'CC'),
#  ('in', 'IN'),
#  ('1981', 'CD'),
#  ('the', 'DT'),
#  ('Commerce', 'NNP'),
#  ('faculty', 'NN'),
#  ('commenced', 'VBD'),
#  ('both', 'DT'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('Junior', 'NNP'),
#  ('and', 'CC'),
#  ('Degree', 'NNP'),
#  ('College', 'NNP'),
#  ('level', 'NN'),
#  ('.', '.'),
#  ('From', 'IN'),
#  ('1999-2000', 'CD'),
#  ('the', 'DT'),
#  ('College', 'NNP'),
#  ('has', 'VBZ'),
#  ('added', 'VBN'),
#  ('a', 'DT'),
#  ('number', 'NN'),
#  ('of', 'IN'),
#  ('self-financing', 'JJ'),
#  ('courses', 'NNS'),
#  ('like', 'IN'),
#  ('BMS', 'NNP'),
#  (',', ','),
#  ('B.B.I', 'NNP'),
#  (',', ','),
#  ('B.Sc', 'NNP'),
#  ('.', '.'),
#  ('in', 'IN'),
#  ('C.S.', 'NNP'),
#  (',', ','),
#  ('I.T.', 'NNP'),
#  (',', ','),
#  ('Biotechnology', 'NNP'),
#  (',', ','),
#  ('M.Sc', 'NNP'),
#  ('.', '.'),
#  ('in', 'IN'),
#  ('Computer', 'NNP'),
#  ('Science', 'NNP'),
#  ('and', 'CC'),
#  ('Biotechnology', 'NNP'),
#  ('as', 'RB'),
#  ('well', 'RB'),
#  ('as', 'IN'),
#  ('add', 'NN'),
#  ('on', 'IN'),
#  ('courses', 'NNS'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('further', 'RB'),
#  ('hone', 'VBD'),
#  ('the', 'DT'),
#  ('special', 'JJ'),
#  ('skills', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('students', 'NNS'),
#  ('.', '.'),
#  ('In', 'IN'),
#  ('2014', 'CD'),
#  ('saw', 'VBD'),
#  ('a', 'DT'),
#  ('change', 'NN'),
#  ('in', 'IN'),
#  ('education', 'NN'),
#  ('system', 'NN'),
#  ('with', 'IN'),
#  ('greater', 'JJR'),
#  ('emphasis', 'NN'),
#  ('being', 'VBG'),
#  ('given', 'VBN'),
#  ('to', 'TO'),
#  ('employability', 'NN'),
#  ('of', 'IN'),
#  ('youth', 'NN'),
#  ('.', '.'),
#  ('As', 'IN'),
#  ('an', 'DT'),
#  ('effort', 'NN'),
#  ('to', 'TO'),
#  ('realize', 'VB'),
#  ('the', 'DT'),
#  ('dream', 'NN'),
#  ('of', 'IN'),
#  ('Make', 'NNP'),
#  ('in', 'IN'),
#  ('India', 'NNP'),
#  (',', ','),
#  ('Digital', 'NNP'),
#  ('India', 'NNP'),
#  (',', ','),
#  ('Clean', 'NNP'),
#  ('and', 'CC'),
#  ('Green', 'NNP'),
#  ('India', 'NNP'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('have', 'VBP'),
#  ('started', 'VBN'),
#  ('skill', 'NNS'),
#  ('based', 'VBN'),
#  ('program', 'NN'),
#  ('supported', 'VBN'),
#  ('by', 'IN'),
#  ('University', 'NNP'),
#  ('Grants', 'NNP'),
#  ('commission', 'NN'),
#  ('known', 'VBN'),
#  ('as', 'IN'),
#  ('Bachelor', 'NNP'),
#  ('in', 'IN'),
#  ('Vocation', 'NNP'),
#  ('.', '.')]

# %%
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package maxent_ne_chunker to C:\Users\Manoj
# [nltk_data]     Yadav\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to C:\Users\Manoj
# [nltk_data]     Yadav\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
ne_tree = nltk.ne_chunk(postags,binary=False)
print(ne_tree)
# Out:
# (S
#   On/IN
#   the/DT
#   auspicious/JJ
#   day/NN
#   of/IN
#   (PERSON Shri/NNP Krishna/NNP Janmashtami/NNP)
#   ,/,
#   15th/CD
#   August/NNP
#   1938/CD
#   ,/,
#   the/DT
#   people/NNS
#   of/IN
#   (GPE Ghatkopar/NNP)
#   and/CC
#   the/DT
#   surrounding/VBG
#   suburbs/NNS
#   witnessed/VBD
#   the/DT
#   birth/NN
#   of/IN
#   (PERSON Hindi/NNP Vidya/NNP Prachar/NNP Samiti/NNP)
#   ,/,
#   a/DT
#   brain/NN
#   child/NN
#   of/IN
#   a/DT
#   visionary/JJ
#   (ORGANIZATION
#     Late/NNP
#     Shri/NNP
#     Nandkishore/NNP
#     Singh/NNP
#     Jairamji/NNP)
#   ./.
#   The/DT
#   (ORGANIZATION Samiti/NNP)
#   was/VBD
#   established/VBN
#   with/IN
#   the/DT
#   objectives/NNS
#   of/IN
#   catering/NN
#   to/TO
#   the/DT
#   educational/JJ
#   needs/NNS
#   of/IN
#   the/DT
#   (ORGANIZATION Hindi/NNP)
#   speaking/NN
#   community/NN
#   ./.
#   It/PRP
#   made/VBD
#   a/DT
#   humble/JJ
#   beginning/NN
#   by/IN
#   starting/VBG
#   a/DT
#   primary/JJ
#   school/NN
#   ,/,
#   which/WDT
#   gradually/RB
#   expanded/VBD
#   into/IN
#   a/DT
#   full-fledged/JJ
#   secondary/JJ
#   school/NN
#   ./.
#   The/DT
#   (ORGANIZATION Hindi/NNP High/NNP School/NNP)
#   with/IN
#   its/PRP$
#   high/JJ
#   academic/JJ
#   standards/NNS
#   has/VBZ
#   carved/VBN
#   for/IN
#   itself/PRP
#   a/DT
#   place/NN
#   not/RB
#   only/RB
#   among/IN
#   leading/VBG
#   secondary/JJ
#   schools/NNS
#   in/IN
#   (GPE Mumbai/NNP)
#   but/CC
#   also/RB
#   educational/JJ
#   institutions/NNS
#   imparting/VBG
#   instructions/NNS
#   in/IN
#   (GPE Hindi/NNP)
#   throughout/IN
#   (GPE Maharashtra/NNP)
#   ./.
#   With/IN
#   its/PRP$
#   primary/JJ
#   objectives/NNS
#   achieved/VBD
#   the/DT
#   (ORGANIZATION Samiti/NNP)
#   decided/VBD
#   to/TO
#   extend/VB
#   its/PRP$
#   frontiers/NNS
#   and/CC
#   broaden/VB
#   its/PRP$
#   horizons/NNS
#   ./.
#   As/IN
#   a/DT
#   result/NN
#   ,/,
#   (PERSON Ramniranjan/NNP Jhunjhunwala/NNP College/NNP)
#   came/VBD
#   into/IN
#   existence/NN
#   in/IN
#   1963/CD
#   ,/,
#   enabling/VBG
#   a/DT
#   larger/JJR
#   section/NN
#   of/IN
#   the/DT
#   society/NN
#   to/TO
#   take/VB
#   advantage/NN
#   of/IN
#   the/DT
#   facilities/NNS
#   provided/VBD
#   for/IN
#   higher/JJR
#   education/NN
#   ./.
#   In/IN
#   1976/CD
#   the/DT
#   (ORGANIZATION Junior/NNP College/NNP)
#   section/NN
#   was/VBD
#   introduced/VBN
#   and/CC
#   in/IN
#   1981/CD
#   the/DT
#   (ORGANIZATION Commerce/NNP)
#   faculty/NN
#   commenced/VBD
#   both/DT
#   at/IN
#   the/DT
#   (ORGANIZATION Junior/NNP)
#   and/CC
#   (PERSON Degree/NNP College/NNP)
#   level/NN
#   ./.
#   From/IN
#   1999-2000/CD
#   the/DT
#   (ORGANIZATION College/NNP)
#   has/VBZ
#   added/VBN
#   a/DT
#   number/NN
#   of/IN
#   self-financing/JJ
#   courses/NNS
#   like/IN
#   (ORGANIZATION BMS/NNP)
#   ,/,
#   B.B.I/NNP
#   ,/,
#   B.Sc/NNP
#   ./.
#   in/IN
#   (GPE C.S./NNP)
#   ,/,
#   I.T./NNP
#   ,/,
#   (GPE Biotechnology/NNP)
#   ,/,
#   M.Sc/NNP
#   ./.
#   in/IN
#   (ORGANIZATION Computer/NNP Science/NNP)
#   and/CC
#   (PERSON Biotechnology/NNP)
#   as/RB
#   well/RB
#   as/IN
#   add/NN
#   on/IN
#   courses/NNS
#   ,/,
#   which/WDT
#   further/RB
#   hone/VBD
#   the/DT
#   special/JJ
#   skills/NNS
#   of/IN
#   the/DT
#   students/NNS
#   ./.
#   In/IN
#   2014/CD
#   saw/VBD
#   a/DT
#   change/NN
#   in/IN
#   education/NN
#   system/NN
#   with/IN
#   greater/JJR
#   emphasis/NN
#   being/VBG
#   given/VBN
#   to/TO
#   employability/NN
#   of/IN
#   youth/NN
#   ./.
#   As/IN
#   an/DT
#   effort/NN
#   to/TO
#   realize/VB
#   the/DT
#   dream/NN
#   of/IN
#   (GPE Make/NNP)
#   in/IN
#   (GPE India/NNP)
#   ,/,
#   (ORGANIZATION Digital/NNP India/NNP)
#   ,/,
#   (GPE Clean/NNP)
#   and/CC
#   (PERSON Green/NNP India/NNP)
#   ,/,
#   we/PRP
#   have/VBP
#   started/VBN
#   skill/NNS
#   based/VBN
#   program/NN
#   supported/VBN
#   by/IN
#   (ORGANIZATION University/NNP Grants/NNP)
#   commission/NN
#   known/VBN
#   as/IN
#   (GPE Bachelor/NNP)
#   in/IN
#   (GPE Vocation/NNP)
#   ./.)

# %%
grammar = "NP: {<NNP>?<NNP>*<IN>*<CD>}" 
cp = nltk.RegexpParser(grammar)
print(cp.parse(postags))
# Out:
# (S
#   On/IN
#   the/DT
#   auspicious/JJ
#   day/NN
#   of/IN
#   Shri/NNP
#   Krishna/NNP
#   Janmashtami/NNP
#   ,/,
#   (NP 15th/CD)
#   (NP August/NNP 1938/CD)
#   ,/,
#   the/DT
#   people/NNS
#   of/IN
#   Ghatkopar/NNP
#   and/CC
#   the/DT
#   surrounding/VBG
#   suburbs/NNS
#   witnessed/VBD
#   the/DT
#   birth/NN
#   of/IN
#   Hindi/NNP
#   Vidya/NNP
#   Prachar/NNP
#   Samiti/NNP
#   ,/,
#   a/DT
#   brain/NN
#   child/NN
#   of/IN
#   a/DT
#   visionary/JJ
#   Late/NNP
#   Shri/NNP
#   Nandkishore/NNP
#   Singh/NNP
#   Jairamji/NNP
#   ./.
#   The/DT
#   Samiti/NNP
#   was/VBD
#   established/VBN
#   with/IN
#   the/DT
#   objectives/NNS
#   of/IN
#   catering/NN
#   to/TO
#   the/DT
#   educational/JJ
#   needs/NNS
#   of/IN
#   the/DT
#   Hindi/NNP
#   speaking/NN
#   community/NN
#   ./.
#   It/PRP
#   made/VBD
#   a/DT
#   humble/JJ
#   beginning/NN
#   by/IN
#   starting/VBG
#   a/DT
#   primary/JJ
#   school/NN
#   ,/,
#   which/WDT
#   gradually/RB
#   expanded/VBD
#   into/IN
#   a/DT
#   full-fledged/JJ
#   secondary/JJ
#   school/NN
#   ./.
#   The/DT
#   Hindi/NNP
#   High/NNP
#   School/NNP
#   with/IN
#   its/PRP$
#   high/JJ
#   academic/JJ
#   standards/NNS
#   has/VBZ
#   carved/VBN
#   for/IN
#   itself/PRP
#   a/DT
#   place/NN
#   not/RB
#   only/RB
#   among/IN
#   leading/VBG
#   secondary/JJ
#   schools/NNS
#   in/IN
#   Mumbai/NNP
#   but/CC
#   also/RB
#   educational/JJ
#   institutions/NNS
#   imparting/VBG
#   instructions/NNS
#   in/IN
#   Hindi/NNP
#   throughout/IN
#   Maharashtra/NNP
#   ./.
#   With/IN
#   its/PRP$
#   primary/JJ
#   objectives/NNS
#   achieved/VBD
#   the/DT
#   Samiti/NNP
#   decided/VBD
#   to/TO
#   extend/VB
#   its/PRP$
#   frontiers/NNS
#   and/CC
#   broaden/VB
#   its/PRP$
#   horizons/NNS
#   ./.
#   As/IN
#   a/DT
#   result/NN
#   ,/,
#   Ramniranjan/NNP
#   Jhunjhunwala/NNP
#   College/NNP
#   came/VBD
#   into/IN
#   existence/NN
#   (NP in/IN 1963/CD)
#   ,/,
#   enabling/VBG
#   a/DT
#   larger/JJR
#   section/NN
#   of/IN
#   the/DT
#   society/NN
#   to/TO
#   take/VB
#   advantage/NN
#   of/IN
#   the/DT
#   facilities/NNS
#   provided/VBD
#   for/IN
#   higher/JJR
#   education/NN
#   ./.
#   (NP In/IN 1976/CD)
#   the/DT
#   Junior/NNP
#   College/NNP
#   section/NN
#   was/VBD
#   introduced/VBN
#   and/CC
#   (NP in/IN 1981/CD)
#   the/DT
#   Commerce/NNP
#   faculty/NN
#   commenced/VBD
#   both/DT
#   at/IN
#   the/DT
#   Junior/NNP
#   and/CC
#   Degree/NNP
#   College/NNP
#   level/NN
#   ./.
#   (NP From/IN 1999-2000/CD)
#   the/DT
#   College/NNP
#   has/VBZ
#   added/VBN
#   a/DT
#   number/NN
#   of/IN
#   self-financing/JJ
#   courses/NNS
#   like/IN
#   BMS/NNP
#   ,/,
#   B.B.I/NNP
#   ,/,
#   B.Sc/NNP
#   ./.
#   in/IN
#   C.S./NNP
#   ,/,
#   I.T./NNP
#   ,/,
#   Biotechnology/NNP
#   ,/,
#   M.Sc/NNP
#   ./.
#   in/IN
#   Computer/NNP
#   Science/NNP
#   and/CC
#   Biotechnology/NNP
#   as/RB
#   well/RB
#   as/IN
#   add/NN
#   on/IN
#   courses/NNS
#   ,/,
#   which/WDT
#   further/RB
#   hone/VBD
#   the/DT
#   special/JJ
#   skills/NNS
#   of/IN
#   the/DT
#   students/NNS
#   ./.
#   (NP In/IN 2014/CD)
#   saw/VBD
#   a/DT
#   change/NN
#   in/IN
#   education/NN
#   system/NN
#   with/IN
#   greater/JJR
#   emphasis/NN
#   being/VBG
#   given/VBN
#   to/TO
#   employability/NN
#   of/IN
#   youth/NN
#   ./.
#   As/IN
#   an/DT
#   effort/NN
#   to/TO
#   realize/VB
#   the/DT
#   dream/NN
#   of/IN
#   Make/NNP
#   in/IN
#   India/NNP
#   ,/,
#   Digital/NNP
#   India/NNP
#   ,/,
#   Clean/NNP
#   and/CC
#   Green/NNP
#   India/NNP
#   ,/,
#   we/PRP
#   have/VBP
#   started/VBN
#   skill/NNS
#   based/VBN
#   program/NN
#   supported/VBN
#   by/IN
#   University/NNP
#   Grants/NNP
#   commission/NN
#   known/VBN
#   as/IN
#   Bachelor/NNP
#   in/IN
#   Vocation/NNP
#   ./.)

# %%
grammar = r"""
  NP:{<.*>+}
  }<NN|CD>+{
"""
cp = nltk.RegexpParser(grammar)
print(cp.parse(postags))
# Out:
# (S
#   (NP On/IN the/DT auspicious/JJ)
#   day/NN
#   (NP of/IN Shri/NNP Krishna/NNP Janmashtami/NNP ,/,)
#   15th/CD
#   (NP August/NNP)
#   1938/CD
#   (NP
#     ,/,
#     the/DT
#     people/NNS
#     of/IN
#     Ghatkopar/NNP
#     and/CC
#     the/DT
#     surrounding/VBG
#     suburbs/NNS
#     witnessed/VBD
#     the/DT)
#   birth/NN
#   (NP of/IN Hindi/NNP Vidya/NNP Prachar/NNP Samiti/NNP ,/, a/DT)
#   brain/NN
#   child/NN
#   (NP
#     of/IN
#     a/DT
#     visionary/JJ
#     Late/NNP
#     Shri/NNP
#     Nandkishore/NNP
#     Singh/NNP
#     Jairamji/NNP
#     ./.
#     The/DT
#     Samiti/NNP
#     was/VBD
#     established/VBN
#     with/IN
#     the/DT
#     objectives/NNS
#     of/IN)
#   catering/NN
#   (NP to/TO the/DT educational/JJ needs/NNS of/IN the/DT Hindi/NNP)
#   speaking/NN
#   community/NN
#   (NP ./. It/PRP made/VBD a/DT humble/JJ)
#   beginning/NN
#   (NP by/IN starting/VBG a/DT primary/JJ)
#   school/NN
#   (NP
#     ,/,
#     which/WDT
#     gradually/RB
#     expanded/VBD
#     into/IN
#     a/DT
#     full-fledged/JJ
#     secondary/JJ)
#   school/NN
#   (NP
#     ./.
#     The/DT
#     Hindi/NNP
#     High/NNP
#     School/NNP
#     with/IN
#     its/PRP$
#     high/JJ
#     academic/JJ
#     standards/NNS
#     has/VBZ
#     carved/VBN
#     for/IN
#     itself/PRP
#     a/DT)
#   place/NN
#   (NP
#     not/RB
#     only/RB
#     among/IN
#     leading/VBG
#     secondary/JJ
#     schools/NNS
#     in/IN
#     Mumbai/NNP
#     but/CC
#     also/RB
#     educational/JJ
#     institutions/NNS
#     imparting/VBG
#     instructions/NNS
#     in/IN
#     Hindi/NNP
#     throughout/IN
#     Maharashtra/NNP
#     ./.
#     With/IN
#     its/PRP$
#     primary/JJ
#     objectives/NNS
#     achieved/VBD
#     the/DT
#     Samiti/NNP
#     decided/VBD
#     to/TO
#     extend/VB
#     its/PRP$
#     frontiers/NNS
#     and/CC
#     broaden/VB
#     its/PRP$
#     horizons/NNS
#     ./.
#     As/IN
#     a/DT)
#   result/NN
#   (NP
#     ,/,
#     Ramniranjan/NNP
#     Jhunjhunwala/NNP
#     College/NNP
#     came/VBD
#     into/IN)
#   existence/NN
#   (NP in/IN)
#   1963/CD
#   (NP ,/, enabling/VBG a/DT larger/JJR)
#   section/NN
#   (NP of/IN the/DT)
#   society/NN
#   (NP to/TO take/VB)
#   advantage/NN
#   (NP of/IN the/DT facilities/NNS provided/VBD for/IN higher/JJR)
#   education/NN
#   (NP ./. In/IN)
#   1976/CD
#   (NP the/DT Junior/NNP College/NNP)
#   section/NN
#   (NP was/VBD introduced/VBN and/CC in/IN)
#   1981/CD
#   (NP the/DT Commerce/NNP)
#   faculty/NN
#   (NP
#     commenced/VBD
#     both/DT
#     at/IN
#     the/DT
#     Junior/NNP
#     and/CC
#     Degree/NNP
#     College/NNP)
#   level/NN
#   (NP ./. From/IN)
#   1999-2000/CD
#   (NP the/DT College/NNP has/VBZ added/VBN a/DT)
#   number/NN
#   (NP
#     of/IN
#     self-financing/JJ
#     courses/NNS
#     like/IN
#     BMS/NNP
#     ,/,
#     B.B.I/NNP
#     ,/,
#     B.Sc/NNP
#     ./.
#     in/IN
#     C.S./NNP
#     ,/,
#     I.T./NNP
#     ,/,
#     Biotechnology/NNP
#     ,/,
#     M.Sc/NNP
#     ./.
#     in/IN
#     Computer/NNP
#     Science/NNP
#     and/CC
#     Biotechnology/NNP
#     as/RB
#     well/RB
#     as/IN)
#   add/NN
#   (NP
#     on/IN
#     courses/NNS
#     ,/,
#     which/WDT
#     further/RB
#     hone/VBD
#     the/DT
#     special/JJ
#     skills/NNS
#     of/IN
#     the/DT
#     students/NNS
#     ./.
#     In/IN)
#   2014/CD
#   (NP saw/VBD a/DT)
#   change/NN
#   (NP in/IN)
#   education/NN
#   system/NN
#   (NP with/IN greater/JJR)
#   emphasis/NN
#   (NP being/VBG given/VBN to/TO)
#   employability/NN
#   (NP of/IN)
#   youth/NN
#   (NP ./. As/IN an/DT)
#   effort/NN
#   (NP to/TO realize/VB the/DT)
#   dream/NN
#   (NP
#     of/IN
#     Make/NNP
#     in/IN
#     India/NNP
#     ,/,
#     Digital/NNP
#     India/NNP
#     ,/,
#     Clean/NNP
#     and/CC
#     Green/NNP
#     India/NNP
#     ,/,
#     we/PRP
#     have/VBP
#     started/VBN
#     skill/NNS
#     based/VBN)
#   program/NN
#   (NP supported/VBN by/IN University/NNP Grants/NNP)
#   commission/NN
#   (NP known/VBN as/IN Bachelor/NNP in/IN Vocation/NNP ./.))

# %%
from nltk.chunk import tree2conlltags
iob_tagged = tree2conlltags(ne_tree)
print(iob_tagged)
# Out:
# [('On', 'IN', 'O'), ('the', 'DT', 'O'), ('auspicious', 'JJ', 'O'), ('day', 'NN', 'O'), ('of', 'IN', 'O'), ('Shri', 'NNP', 'B-PERSON'), ('Krishna', 'NNP', 'I-PERSON'), ('Janmashtami', 'NNP', 'I-PERSON'), (',', ',', 'O'), ('15th', 'CD', 'O'), ('August', 'NNP', 'O'), ('1938', 'CD', 'O'), (',', ',', 'O'), ('the', 'DT', 'O'), ('people', 'NNS', 'O'), ('of', 'IN', 'O'), ('Ghatkopar', 'NNP', 'B-GPE'), ('and', 'CC', 'O'), ('the', 'DT', 'O'), ('surrounding', 'VBG', 'O'), ('suburbs', 'NNS', 'O'), ('witnessed', 'VBD', 'O'), ('the', 'DT', 'O'), ('birth', 'NN', 'O'), ('of', 'IN', 'O'), ('Hindi', 'NNP', 'B-PERSON'), ('Vidya', 'NNP', 'I-PERSON'), ('Prachar', 'NNP', 'I-PERSON'), ('Samiti', 'NNP', 'I-PERSON'), (',', ',', 'O'), ('a', 'DT', 'O'), ('brain', 'NN', 'O'), ('child', 'NN', 'O'), ('of', 'IN', 'O'), ('a', 'DT', 'O'), ('visionary', 'JJ', 'O'), ('Late', 'NNP', 'B-ORGANIZATION'), ('Shri', 'NNP', 'I-ORGANIZATION'), ('Nandkishore', 'NNP', 'I-ORGANIZATION'), ('Singh', 'NNP', 'I-ORGANIZATION'), ('Jairamji', 'NNP', 'I-ORGANIZATION'), ('.', '.', 'O'), ('The', 'DT', 'O'), ('Samiti', 'NNP', 'B-ORGANIZATION'), ('was', 'VBD', 'O'), ('established', 'VBN', 'O'), ('with', 'IN', 'O'), ('the', 'DT', 'O'), ('objectives', 'NNS', 'O'), ('of', 'IN', 'O'), ('catering', 'NN', 'O'), ('to', 'TO', 'O'), ('the', 'DT', 'O'), ('educational', 'JJ', 'O'), ('needs', 'NNS', 'O'), ('of', 'IN', 'O'), ('the', 'DT', 'O'), ('Hindi', 'NNP', 'B-ORGANIZATION'), ('speaking', 'NN', 'O'), ('community', 'NN', 'O'), ('.', '.', 'O'), ('It', 'PRP', 'O'), ('made', 'VBD', 'O'), ('a', 'DT', 'O'), ('humble', 'JJ', 'O'), ('beginning', 'NN', 'O'), ('by', 'IN', 'O'), ('starting', 'VBG', 'O'), ('a', 'DT', 'O'), ('primary', 'JJ', 'O'), ('school', 'NN', 'O'), (',', ',', 'O'), ('which', 'WDT', 'O'), ('gradually', 'RB', 'O'), ('expanded', 'VBD', 'O'), ('into', 'IN', 'O'), ('a', 'DT', 'O'), ('full-fledged', 'JJ', 'O'), ('secondary', 'JJ', 'O'), ('school', 'NN', 'O'), ('.', '.', 'O'), ('The', 'DT', 'O'), ('Hindi', 'NNP', 'B-ORGANIZATION'), ('High', 'NNP', 'I-ORGANIZATION'), ('School', 'NNP', 'I-ORGANIZATION'), ('with', 'IN', 'O'), ('its', 'PRP$', 'O'), ('high', 'JJ', 'O'), ('academic', 'JJ', 'O'), ('standards', 'NNS', 'O'), ('has', 'VBZ', 'O'), ('carved', 'VBN', 'O'), ('for', 'IN', 'O'), ('itself', 'PRP', 'O'), ('a', 'DT', 'O'), ('place', 'NN', 'O'), ('not', 'RB', 'O'), ('only', 'RB', 'O'), ('among', 'IN', 'O'), ('leading', 'VBG', 'O'), ('secondary', 'JJ', 'O'), ('schools', 'NNS', 'O'), ('in', 'IN', 'O'), ('Mumbai', 'NNP', 'B-GPE'), ('but', 'CC', 'O'), ('also', 'RB', 'O'), ('educational', 'JJ', 'O'), ('institutions', 'NNS', 'O'), ('imparting', 'VBG', 'O'), ('instructions', 'NNS', 'O'), ('in', 'IN', 'O'), ('Hindi', 'NNP', 'B-GPE'), ('throughout', 'IN', 'O'), ('Maharashtra', 'NNP', 'B-GPE'), ('.', '.', 'O'), ('With', 'IN', 'O'), ('its', 'PRP$', 'O'), ('primary', 'JJ', 'O'), ('objectives', 'NNS', 'O'), ('achieved', 'VBD', 'O'), ('the', 'DT', 'O'), ('Samiti', 'NNP', 'B-ORGANIZATION'), ('decided', 'VBD', 'O'), ('to', 'TO', 'O'), ('extend', 'VB', 'O'), ('its', 'PRP$', 'O'), ('frontiers', 'NNS', 'O'), ('and', 'CC', 'O'), ('broaden', 'VB', 'O'), ('its', 'PRP$', 'O'), ('horizons', 'NNS', 'O'), ('.', '.', 'O'), ('As', 'IN', 'O'), ('a', 'DT', 'O'), ('result', 'NN', 'O'), (',', ',', 'O'), ('Ramniranjan', 'NNP', 'B-PERSON'), ('Jhunjhunwala', 'NNP', 'I-PERSON'), ('College', 'NNP', 'I-PERSON'), ('came', 'VBD', 'O'), ('into', 'IN', 'O'), ('existence', 'NN', 'O'), ('in', 'IN', 'O'), ('1963', 'CD', 'O'), (',', ',', 'O'), ('enabling', 'VBG', 'O'), ('a', 'DT', 'O'), ('larger', 'JJR', 'O'), ('section', 'NN', 'O'), ('of', 'IN', 'O'), ('the', 'DT', 'O'), ('society', 'NN', 'O'), ('to', 'TO', 'O'), ('take', 'VB', 'O'), ('advantage', 'NN', 'O'), ('of', 'IN', 'O'), ('the', 'DT', 'O'), ('facilities', 'NNS', 'O'), ('provided', 'VBD', 'O'), ('for', 'IN', 'O'), ('higher', 'JJR', 'O'), ('education', 'NN', 'O'), ('.', '.', 'O'), ('In', 'IN', 'O'), ('1976', 'CD', 'O'), ('the', 'DT', 'O'), ('Junior', 'NNP', 'B-ORGANIZATION'), ('Colle ...
